# %% [markdown]
# # LVQ x2 implementation in  python

# %% [markdown]
# We first import two useful libraries
# 1. numpy (matrix algebra):  we use np as a shortcut
# 2. plyplot from matplotlib: useful for plotting charts: we use plt as a shortcut
# 3. use tab and shift+tab for help

# %%
import numpy as np
import matplotlib.pyplot as plt
import LVQUtils as lu

# %%
# this line plots graphs in line
# %matplotlib inline

# %% [markdown]
# ### First we generate a dataset

# %%
# C_g is the array for centroids
# 
M_g = 3
np.random.seed(3)

# %%
theta_deg = np.arange(0.0,181.0,10.0)
theta_rad = theta_deg*(np.pi/180.0)
C_g = np.zeros((len(theta_deg),2))
C_g[:,0]=np.cos(theta_rad)/2.5+0.5
C_g[:,1]=np.sin(theta_rad)/1.5+0.25

plt.figure()
plt.plot(C_g[:,0],C_g[:,1],'o')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
simple=False
if (simple):
    # we can also choose the centroids arbitarily
    C_g=np.array([[.25,.25],
                 [.75,.5],
                 [.45,.75]])
    
    
    # In[6]:
    
    
    # Generate data set ( M=3, centroid, constant sigma)
    #
    sigma=0.095
    number=100
    #
    # storing the centroid index (note this may not correspond to teh same number from the k-means algorithm)
    X11=np.concatenate((sigma*np.random.randn(number,2)+C_g[0],np.full((number,1),0.0)),axis=1)
    X22=np.concatenate((sigma*np.random.randn(number,2)+C_g[1],np.full((number,1),1.0)),axis=1)
    X33=np.concatenate((sigma*np.random.randn(number,2)+C_g[2],np.full((number,1),2.0)),axis=1)
    #
    #X=np.concatenate((X1,X2,X3), axis=0)
    X=np.concatenate((X11,X22,X33), axis=0)
else:
    # Generate data set ( M=3, centroid, constant sigma)
    #
    sigma=0.04
    number=20
    number0=200
    #
    # storing the centroid index (note this may not correspond to teh same number from the k-means algorithm)
    #X1=np.concatenate((1.3*sigma*np.random.randn(number0,2)+C_g[0],np.full((number0,1),0.0)),axis=1)
    X=np.zeros([number*len(C_g[:,0])+number0,3])
    for i in range(len(C_g[:,0])):
        #print i
        X[i*number:(i*number)+number,:]=np.concatenate((sigma*np.random.randn(number,2)+C_g[i],np.full((number,1),1.0)),axis=1)
    
    i = len(C_g[:,0])
    #print sigma*np.random.randn(number0,2)+np.array([0.5,0.5]
    X[i*number:(i*number)+number0,:]=np.concatenate((sigma*np.random.randn(number0,2)+np.array([0.5,0.4]),np.full((number0,1),2.0)),axis=1)



#
#X=np.concatenate((X1,X2,X3), axis=0)
#X=np.concatenate((X1,X2,X3,X4,X5,X6,X7,X8), axis=0)
np.random.shuffle(X)
print(X.shape)
# Out:
# (580, 3)

# %%
# plot data set and centroids
plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
col={0:'bo',1:'go', 2:'co'}
for i in range(len(X[:,0])):
    plt.plot(X[i,0],X[i,1],col[int(X[i,2])])

plt.plot(C_g[:,0],C_g[:,1],'ro')
plt.axis([0, 1.5, 0, 1.5])
plt.show()

# %%
#split data set into train and test
split = int((len(X[:,0]))*0.7)
print("Split point = ",split)
X_train=np.asarray(X[0:split,:])
print("Train size = ",len(X_train[:,0]))
X_test=np.asarray(X[split:,:])
print("Test size =",len(X_test[:,0]))
# Out:
# ('Split point = ', 406)
# ('Train size = ', 406)
# ('Test size =', 174)

# %%
# LVQ Training function
def trainLVQ(trainData, initPrt, epochs, rateFunc):
    Prot=initPrt.copy()
    for t in range(0,epochs):
        for f in range(0, len(trainData[:,0])):
            feature=trainData[f,:]
            #print(feature)
        #    print(get_nearest_prototype(feature, Prt))    
            (dist, cls) = lu.get_nearest_prototype(feature[0:-1], Prot)
        #    print("dist=", dist, ", cls=", cls)
    #        print(Prt[cls[0],2])
            prt = Prot[cls[0],0:-1]
            if (Prot[cls[0],-1]==feature[-1]):    
        #        print("Match ->", Prt[cls[0],:], "=", feature)
                newPrt = prt + rateFunc(t) * (feature[0:-1]-prt)
#                print("Match: Old Prt=", prt, ", new Prt=", Prt[cls[0],0:-1], ", rate=", rateFunc(t))
            else:
            #    print("No Match ->", Prt[cls[0],:], "!=", feature)
                newPrt = prt - rateFunc(t) * (feature[0:-1]-prt)                        
                
            Prot[cls[0],0:-1] =     newPrt            

#            prt = Prot[cls[1],0:-1]
#            if (Prot[cls[1],-1]==feature[-1]):    
#        #        print("Match ->", Prt[cls[0],:], "=", feature)
#                newPrt = prt + rateFunc(t) * 0.5 * (feature[0:-1]-prt)
##                print("Match: Old Prt=", prt, ", new Prt=", Prt[cls[0],0:-1], ", rate=", rateFunc(t))
#            else:
#            #    print("No Match ->", Prt[cls[0],:], "!=", feature)
#                newPrt = prt - rateFunc(t) * 0.5 * (feature[0:-1]-prt)                        
#                
#            Prot[cls[1],0:-1] =     newPrt                
    #            print("MisMatch: Old Prt=", prt, ", new Prt=", Prt[cls[0],0:-1], ", rate=", rateFunc(t))            
#        plt.figure()
#        plt.title("t="+str(t))
#        col={0:'bo',1:'go', 2:'co'}
#        for i in range(len(trainData[:,0])):
#            plt.plot(trainData[i,0],trainData[i,1], "kx")#col[int(trainData[i,2])])
#        
#        for i in range(0,len(Prot[:,0])):
#            plt.plot(Prot[i,0],Prot[i,1],col[int(Prot[i,2])])
#            
#        plt.axis([0, 1.5, 0, 1.5])
#        plt.show()
    return Prot

# %%
requiredAccuracy=0.8
numProtos=50

#labelSpec=np.reshape([0, numProtos, 1, numProtos, 2, numProtos], (3,2))
labelSpec=np.reshape([1, numProtos, 2, numProtos], (2,2))
print(labelSpec)

limits=np.reshape([np.min(X[:,0]), np.max(X[:,0]), np.min(X[:,1]), np.max(X[:,1])], (2,2))

print("Limits=", limits)
Prt = lu.genPrototypes(labelSpec, limits)

plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
col={0:'bo',1:'go', 2:'co'}
for i in range(len(X[:,0])):
    plt.plot(X[i,0],X[i,1],col[int(X[i,2])])
    
plt.plot(Prt[:,0],Prt[:,1],'ro')
plt.axis([0, 1.5, 0, 1.5])
plt.show()
# Out:
# [[ 1 50]
#  [ 2 50]]
# ('Limits=', array([[ 0.02782047,  0.97154514],
#        [ 0.15323667,  0.98519749]]))
# ('C=', 2)
# ('dim=', 2)

# %%
trainedPrt = trainLVQ(X_train, Prt, 20, lambda t: 0.5*np.exp(-0.1*t))
#trimmedPrt = trainedPrt.copy()
trimmedPrt = trainedPrt[trainedPrt[:,0]!=Prt[:,0],:]
span = limits[:,1]-limits[:,0]
trimmedPrt = trimmedPrt[(trimmedPrt[:,0]>limits[0,0]-(3*span[0]))]
trimmedPrt = trimmedPrt[(trimmedPrt[:,0]<limits[0,1]+(3*span[0]))]
trimmedPrt = trimmedPrt[(trimmedPrt[:,0]>limits[1,0]-(3*span[1]))]
trimmedPrt = trimmedPrt[(trimmedPrt[:,0]<limits[1,1]+(3*span[1]))]
deadPrt = trainedPrt[trainedPrt[:,0]==Prt[:,0],:]
print("Trimmed prototype set from", len(Prt[:,0]), "points to" , len(trimmedPrt[:,0]), "points")
#print(len(deadPrt[:,0]))
#print( "Trained Prototypes=", trainedPrt)

print(trimmedPrt)
plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.title("Trained Prototypes")
col={0:'bo',1:'go', 2:'co'}
for i in range(len(X_train[:,0])):
    plt.plot(X_train[i,0],X_train[i,1],col[int(X_train[i,2])])

plt.plot(trimmedPrt[:,0],trimmedPrt[:,1],'ro')
plt.plot(deadPrt[:,0],deadPrt[:,1],'k.')
plt.axis([np.min(trimmedPrt[:,0]), np.max(trimmedPrt[:,0]), np.min(trimmedPrt[:,1]), np.max(trimmedPrt[:,1])])
plt.show()
# Out:
# ('Trimmed prototype set from', 100, 'points to', 76, 'points')
# [[ 0.81067758  0.61191157  1.        ]
#  [ 0.32840628  0.79983336  1.        ]
#  [ 0.5738292   0.93220678  1.        ]
#  [ 0.20305788  0.67267962  1.        ]
#  [ 0.75910031  0.43875259  1.        ]
#  [ 0.49081433  0.92142477  1.        ]
#  [ 0.415276    0.90112349  1.        ]
#  [ 0.11048249  0.52477562  1.        ]
#  [ 0.10251166  0.36826651  1.        ]
#  [ 0.72508067  0.63999338  1.        ]
#  [ 0.67289443  0.44206282  1.        ]
#  [ 0.31626173  0.88442817  1.        ]
#  [ 0.33156793  0.45044589  1.        ]
#  [ 0.65775291  0.81150006  1.        ]
#  [ 0.58497705  0.17093041  1.        ]
#  [ 0.69740429  0.91527218  1.        ]
#  [ 0.88770938  0.22457221  1.        ]
#  [ 0.86973782  0.57016665  1.        ]
#  [ 0.87078976  0.77197423  1.        ]
#  [ 0.16394988  0.60499109  1.        ]
#  [ 0.33874475  0.41724858  1.        ]
#  [ 0.73811754  0.82641614  1.        ]
#  [ 0.87493564  0.47779867  1.        ]
#  [ 0.24456008  0.76640074  1.        ]
#  [ 0.33290275  0.43217254  1.        ]
#  [ 0.85239939  0.66771895  1.        ]
#  [ 0.59835976  0.58420031  1.        ]
#  [ 0.6118127   0.86416434  1.        ]
#  [ 0.76867453  0.75870494  1.        ]
#  [ 0.80913973  0.8517966   1.        ]
#  [ 0.91505459  0.29205787  1.        ]
#  [ 0.32192807  0.42103883  1.        ]
#  [ 0.77740523  0.67766001  1.        ]
#  [ 0.8506463   0.37586244  1.        ]
#  [ 0.28114012  0.29002302  1.        ]
#  [ 0.0937409   0.25137531  1.        ]
#  [ 0.92336868  0.40249514  1.        ]
#  [ 0.45848131  1.05868413  2.        ]
#  [ 0.30962214  0.55087529  2.        ]
#  [ 0.23644875  0.34672725  2.        ]
#  [ 0.82617104  0.83835236  2.        ]
#  [ 0.31001418  0.54512211  2.        ]
#  [ 0.99430487  0.17886409  2.        ]
#  [ 0.99678594  0.18503962  2.        ]
#  [ 0.25116466  0.97381492  2.        ]
#  [-0.01982081  0.27583571  2.        ]
#  [ 0.91145972  0.75525706  2.        ]
#  [ 0.4414469   0.43809124  2.        ]
#  [ 0.8513884   0.79665264  2.        ]
#  [ 0.49054334  1.04960161  2.        ]
#  [ 0.48389288  0.3504453   2.        ]
#  [ 0.07454528  0.75776282  2.        ]
#  [ 0.31835326  0.47542504  2.        ]
#  [ 0.34989837  0.58721661  2.        ]
#  [ 0.35567397  0.61326683  2.        ]
#  [ 0.51692237  0.44953763  2.        ]
#  [ 0.94376087  0.59270222  2.        ]
#  [ 0.30655577  0.55251924  2.        ]
#  [ 0.11688599  0.87069609  2.        ]
#  [ 0.84125406  0.82218531  2.        ]
#  [ 0.59799623  0.70459768  2.        ]
#  [ 0.99657798  0.18163178  2.        ]
#  [ 0.37992262  0.34122912  2.        ]
#  [ 0.95106243  0.75843694  2.        ]
#  [ 0.1567771   0.87380038  2.        ]
#  [ 0.00251378  0.62561987  2.        ]
#  [ 0.49781392  0.39639897  2.        ]
#  [ 1.01031778  0.36651988  2.        ]
#  [ 0.10556176  0.84007749  2.        ]
#  [ 0.09004122  0.84258189  2.        ]
#  [ 0.24811548  0.96644536  2.        ]
#  [ 0.15037428  0.88894663  2.        ]
#  [ 0.55082578  0.40446646  2.        ]
#  [-0.02214527  0.28350047  2.        ]
#  [ 0.67875547  0.6953464   2.        ]
#  [ 0.04169789  0.67047052  2.        ]]

# %%
def runTestSet(X_test, Prots):
    # Do test set
    predictedClasses = X_test[:,-1].copy()
    
    for i in range(0, len(X_test[:,0])):
        (dist,cls) = lu.get_nearest_prototype(X_test[i,0:-1], Prots)
        predictedClasses[i] = Prots[cls[0],-1]
        
    return predictedClasses

# %%
predictedClasses = runTestSet(X_test, trimmedPrt)

# %%
plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.title("Test set classification")
col={0:'bo',1:'go', 2:'co'}
for i in range(len(X_test[:,0])):
    plt.plot(X_test[i,0],X_test[i,1],col[int(predictedClasses[i])])

plt.plot(trimmedPrt[:,0],trimmedPrt[:,1],'ro')

plt.axis([0, 1.5, 0, 1.5])
plt.show()

# %%
# Calculate accuracy
accuracy = float(sum(predictedClasses==X_test[:,-1]))/len(X_test[:,0])
print("Accuracy(", len(trimmedPrt[:,0]), ")=", accuracy)

unoptimizedAccuracy = accuracy
# Try removing prototypes at random
# Remove 20% at every iteration until accuracy drops to < 95%
prots = trimmedPrt.copy()

trialsPerStep=10

reducedAccuracy=0
bestReducedPrt = trimmedPrt
while (len(prots[:,0]>=1)):
    print("-------------------------------------------------")        
    print("Trying ", trialsPerStep, "reductions of ", len(prots[:,0]), "prototypes...")
    print("reducedAccuracy=", reducedAccuracy)
    
    localBestAcc=0
    localBestPrt=bestReducedPrt
    for i in range(0, trialsPerStep):    

        rndNdx = (np.random.rand(int(len(prots[:,0])*0.2))*len(prots[:,0])).astype(int)
        print(rndNdx)
        mask = np.ones(len(prots[:,0]),dtype=bool) #np.ones_like(a,dtype=bool)
        mask[rndNdx] = False
            
        reducedPrt = prots[mask,:]
        
        print("mask len = ", len(mask))
        print("mask true=", sum(mask))
        print("reducedPrt len=", len(reducedPrt[:,0]))
        print("prots len=", len(prots[:,0]))
        if (len(reducedPrt[:,0]) == len(prots[:,0])):
            break
            
        predictedClasses = runTestSet(X_test, reducedPrt)
        
#        print("predictedClasses len=", len(predictedClasses))
#        print("X_test len=", len(X_test[:,-1]))
#        print(predictedClasses==X_test[:,-1])
#        print(sum(predictedClasses==X_test[:,-1]))
#        print(reducedPrt)
        acc = float(sum(predictedClasses==X_test[:,-1]))/len(X_test[:,0])
        print("trial acc=", acc)
        if (acc >= reducedAccuracy):
            localBestAcc=acc
            localBestPrt = reducedPrt.copy()    
    
    print("localBestAcc=", localBestAcc)
    print("localBestPrt=", localBestPrt)
    
    if (localBestAcc >= reducedAccuracy):
        reducedAccuracy = localBestAcc
        bestReducedPrt = localBestPrt.copy()
    else:
        break    

    prots = bestReducedPrt.copy()
    
    print("Accuracy with ", len(prots[:,0]), "prototypes=", reducedAccuracy)
#    if (len(prots[:,0])<=4):
#        break

prots = bestReducedPrt.copy()        
print("Best params: ",len(prots[:,0]), " at accuracy=", reducedAccuracy)
print(prots)
# Out:
# ('Accuracy(', 73, ')=', 0.9655172413793104)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 73, 'prototypes...')
# ('reducedAccuracy=', 0)
# [20 37  7 61 59 17 59 61 43 15 68 37 43 67]
# ('mask len = ', 73)
# ('mask true=', 63)
# ('reducedPrt len=', 63)
# ('prots len=', 73)
# ('trial acc=', 0.9597701149425287)
# [18 49 45 38 64 69 26 62 39 43 49 28 22 66]
# ('mask len = ', 73)
# ('mask true=', 60)
# ('reducedPrt len=', 60)
# ('prots len=', 73)
# ('trial acc=', 0.9597701149425287)
# [17  9 42 32 22 57 46 71 12 48 20 47 15 60]
# ('mask len = ', 73)
# ('mask true=', 59)
# ('reducedPrt len=', 59)
# ('prots len=', 73)
# ('trial acc=', 0.9597701149425287)
# [28 21 34 26 41 51 65 69 28  6 34  4 47  3]
# ('mask len = ', 73)
# ('mask true=', 61)
# ('reducedPrt len=', 61)
# ('prots len=', 73)
# ('trial acc=', 0.9195402298850575)
# [60 53 29 57 48 34 61  1 64  2 59 30 47 39]
# ('mask len = ', 73)
# ('mask true=', 59)
# ('reducedPrt len=', 59)
# ('prots len=', 73)
# ('trial acc=', 0.9367816091954023)
# [58 62  5  9 24 19 31 51 43 51 46 23 24 18]
# ('mask len = ', 73)
# ('mask true=', 61)
# ('reducedPrt len=', 61)
# ('prots len=', 73)
# ('trial acc=', 0.9597701149425287)
# [51 20 43 35  7 30 18 26 71 63 16 71 26 45]
# ('mask len = ', 73)
# ('mask true=', 61)
# ('reducedPrt len=', 61)
# ('prots len=', 73)
# ('trial acc=', 0.9252873563218391)
# [51 60  0 19 29 18 22 55 11 68 17 60 16 71]
# ('mask len = ', 73)
# ('mask true=', 60)
# ('reducedPrt len=', 60)
# ('prots len=', 73)
# ('trial acc=', 0.9597701149425287)
# [68 29 35 15 62 23 56 37 67 12 30 40 16 69]
# ('mask len = ', 73)
# ('mask true=', 59)
# ('reducedPrt len=', 59)
# ('prots len=', 73)
# ('trial acc=', 0.9540229885057471)
# [69 42 48 49 12  5 13 14 13 15 47 62 61 24]
# ('mask len = ', 73)
# ('mask true=', 60)
# ('reducedPrt len=', 60)
# ('prots len=', 73)
# ('trial acc=', 0.9540229885057471)
# ('localBestAcc=', 0.9540229885057471)
# ('localBestPrt=', array([[ 0.71299843,  0.91362915,  1.        ],
#        [ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.44943903,  0.24386551,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.11498628,  0.53901964,  1.        ],
#        [ 0.27890872,  0.77322832,  1.        ],
#        [ 0.64222909,  0.89145258,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.89558202,  0.30659203,  1.        ],
#        [ 0.41521293,  0.24886094,  1.        ],
#        [ 0.09318649,  0.28604325,  1.        ],
#        [ 0.76575605,  0.67413218,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.08993341,  0.21545752,  1.        ],
#        [ 0.80866933,  0.85248161,  1.        ],
#        [ 0.87867088,  0.22345283,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.49295834,  0.88989729,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.28470453,  0.34562658,  1.        ],
#        [ 0.5922757 ,  0.85302914,  1.        ],
#        [ 0.19351653,  0.71856505,  1.        ],
#        [ 0.42313618,  0.25440686,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.92038979,  0.56842736,  2.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.0457057 ,  0.68898032,  2.        ],
#        [ 0.04308614,  0.66669524,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.71323723,  0.51724318,  2.        ],
#        [ 0.93299347,  0.57238019,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.08071992,  0.73840553,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [-0.01397764,  0.29784787,  2.        ],
#        [ 0.97495786,  0.60074912,  2.        ],
#        [-0.00549228,  0.42834361,  2.        ],
#        [ 0.1991565 ,  0.28412126,  2.        ],
#        [ 0.5084808 ,  0.39492942,  2.        ],
#        [ 0.0917743 ,  0.43405321,  2.        ],
#        [ 0.92600829,  0.57457282,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.41258179,  0.6470856 ,  2.        ],
#        [-0.0341532 ,  0.47227723,  2.        ],
#        [ 0.81525228,  0.98965619,  2.        ],
#        [ 0.09879847,  0.86259056,  2.        ],
#        [ 0.10741981,  0.85986282,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ],
#        [ 0.60333241,  1.04298525,  2.        ],
#        [ 0.71426265,  0.2564895 ,  2.        ],
#        [ 0.07131628,  0.70995671,  2.        ],
#        [ 0.4650707 ,  0.37652736,  2.        ]]))
# ('Accuracy with ', 60, 'prototypes=', 0.9540229885057471)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 60, 'prototypes...')
# ('reducedAccuracy=', 0.9540229885057471)
# [51 27  7 18 45  2 54 53 34 37 32 18]
# ('mask len = ', 60)
# ('mask true=', 49)
# ('reducedPrt len=', 49)
# ('prots len=', 60)
# ('trial acc=', 0.9597701149425287)
# [59 48 34 56 24 26  4 55 10 19 22 50]
# ('mask len = ', 60)
# ('mask true=', 48)
# ('reducedPrt len=', 48)
# ('prots len=', 60)
# ('trial acc=', 0.9080459770114943)
# [28 24  9 22 40 13 24 23 33 27 24  4]
# ('mask len = ', 60)
# ('mask true=', 50)
# ('reducedPrt len=', 50)
# ('prots len=', 60)
# ('trial acc=', 0.9195402298850575)
# [23  3 19 22 48 44 54  8 39  5  2 29]
# ('mask len = ', 60)
# ('mask true=', 48)
# ('reducedPrt len=', 48)
# ('prots len=', 60)
# ('trial acc=', 0.9310344827586207)
# [27 39 23  8 27  2 27 24 29 27  4 44]
# ('mask len = ', 60)
# ('mask true=', 51)
# ('reducedPrt len=', 51)
# ('prots len=', 60)
# ('trial acc=', 0.9252873563218391)
# [45 57 24 35 37 41 14 10 45 36 27 39]
# ('mask len = ', 60)
# ('mask true=', 49)
# ('reducedPrt len=', 49)
# ('prots len=', 60)
# ('trial acc=', 0.9137931034482759)
# [48 10 26 58 32 12 34 59 19 28 12 44]
# ('mask len = ', 60)
# ('mask true=', 49)
# ('reducedPrt len=', 49)
# ('prots len=', 60)
# ('trial acc=', 0.9022988505747126)
# [15 46  2 40 33 32  9  1 25 48 57 52]
# ('mask len = ', 60)
# ('mask true=', 48)
# ('reducedPrt len=', 48)
# ('prots len=', 60)
# ('trial acc=', 0.9540229885057471)
# [52  7 42 48 57 29 37 51 27 44 44  0]
# ('mask len = ', 60)
# ('mask true=', 49)
# ('reducedPrt len=', 49)
# ('prots len=', 60)
# ('trial acc=', 0.9597701149425287)
# [29 48 10 45 41  7 26 13 47  9 16 59]
# ('mask len = ', 60)
# ('mask true=', 48)
# ('reducedPrt len=', 48)
# ('prots len=', 60)
# ('trial acc=', 0.8735632183908046)
# ('localBestAcc=', 0.9597701149425287)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.44943903,  0.24386551,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.11498628,  0.53901964,  1.        ],
#        [ 0.64222909,  0.89145258,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.89558202,  0.30659203,  1.        ],
#        [ 0.41521293,  0.24886094,  1.        ],
#        [ 0.09318649,  0.28604325,  1.        ],
#        [ 0.76575605,  0.67413218,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.08993341,  0.21545752,  1.        ],
#        [ 0.80866933,  0.85248161,  1.        ],
#        [ 0.87867088,  0.22345283,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.49295834,  0.88989729,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.28470453,  0.34562658,  1.        ],
#        [ 0.19351653,  0.71856505,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.92038979,  0.56842736,  2.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.0457057 ,  0.68898032,  2.        ],
#        [ 0.04308614,  0.66669524,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.93299347,  0.57238019,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.08071992,  0.73840553,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [ 0.97495786,  0.60074912,  2.        ],
#        [ 0.1991565 ,  0.28412126,  2.        ],
#        [ 0.5084808 ,  0.39492942,  2.        ],
#        [ 0.0917743 ,  0.43405321,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.41258179,  0.6470856 ,  2.        ],
#        [ 0.09879847,  0.86259056,  2.        ],
#        [ 0.10741981,  0.85986282,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ],
#        [ 0.60333241,  1.04298525,  2.        ],
#        [ 0.07131628,  0.70995671,  2.        ],
#        [ 0.4650707 ,  0.37652736,  2.        ]]))
# ('Accuracy with ', 49, 'prototypes=', 0.9597701149425287)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 49, 'prototypes...')
# ('reducedAccuracy=', 0.9597701149425287)
# [21 10 40 30 27 34  9 25 10]
# ('mask len = ', 49)
# ('mask true=', 41)
# ('reducedPrt len=', 41)
# ('prots len=', 49)
# ('trial acc=', 0.9597701149425287)
# [48 19 39 47  7 22 29 19 20]
# ('mask len = ', 49)
# ('mask true=', 41)
# ('reducedPrt len=', 41)
# ('prots len=', 49)
# ('trial acc=', 0.9252873563218391)
# [22 26 21 36 21 17 22  7 47]
# ('mask len = ', 49)
# ('mask true=', 42)
# ('reducedPrt len=', 42)
# ('prots len=', 49)
# ('trial acc=', 0.9367816091954023)
# [ 7 29 15 38 27 10 11 22 46]
# ('mask len = ', 49)
# ('mask true=', 40)
# ('reducedPrt len=', 40)
# ('prots len=', 49)
# ('trial acc=', 0.9252873563218391)
# [32 14 33 40 12 25  6 41 20]
# ('mask len = ', 49)
# ('mask true=', 40)
# ('reducedPrt len=', 40)
# ('prots len=', 49)
# ('trial acc=', 0.9252873563218391)
# [25  0 24 38 27 17 36 27  4]
# ('mask len = ', 49)
# ('mask true=', 41)
# ('reducedPrt len=', 41)
# ('prots len=', 49)
# ('trial acc=', 0.867816091954023)
# [46 24 32 29  6 32 15  7 27]
# ('mask len = ', 49)
# ('mask true=', 41)
# ('reducedPrt len=', 41)
# ('prots len=', 49)
# ('trial acc=', 0.9597701149425287)
# [31 30 34 26 18 38  5  9 11]
# ('mask len = ', 49)
# ('mask true=', 40)
# ('reducedPrt len=', 40)
# ('prots len=', 49)
# ('trial acc=', 0.9482758620689655)
# [35 13 48 38 13 16 40 16 12]
# ('mask len = ', 49)
# ('mask true=', 42)
# ('reducedPrt len=', 42)
# ('prots len=', 49)
# ('trial acc=', 0.9655172413793104)
# [27 28 15 28 18  9 39 19 13]
# ('mask len = ', 49)
# ('mask true=', 41)
# ('reducedPrt len=', 41)
# ('prots len=', 49)
# ('trial acc=', 0.9540229885057471)
# ('localBestAcc=', 0.9655172413793104)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.44943903,  0.24386551,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.11498628,  0.53901964,  1.        ],
#        [ 0.64222909,  0.89145258,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.89558202,  0.30659203,  1.        ],
#        [ 0.76575605,  0.67413218,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.80866933,  0.85248161,  1.        ],
#        [ 0.87867088,  0.22345283,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.49295834,  0.88989729,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.28470453,  0.34562658,  1.        ],
#        [ 0.19351653,  0.71856505,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.92038979,  0.56842736,  2.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.0457057 ,  0.68898032,  2.        ],
#        [ 0.04308614,  0.66669524,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.93299347,  0.57238019,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [ 0.97495786,  0.60074912,  2.        ],
#        [ 0.5084808 ,  0.39492942,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.41258179,  0.6470856 ,  2.        ],
#        [ 0.09879847,  0.86259056,  2.        ],
#        [ 0.10741981,  0.85986282,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ],
#        [ 0.60333241,  1.04298525,  2.        ],
#        [ 0.07131628,  0.70995671,  2.        ]]))
# ('Accuracy with ', 42, 'prototypes=', 0.9655172413793104)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 42, 'prototypes...')
# ('reducedAccuracy=', 0.9655172413793104)
# [28 24  9  8 13 14 30 20]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9712643678160919)
# [14 31 26 19 21 10 27 38]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9482758620689655)
# [19  9 32 31 38 19 39 35]
# ('mask len = ', 42)
# ('mask true=', 35)
# ('reducedPrt len=', 35)
# ('prots len=', 42)
# ('trial acc=', 0.9597701149425287)
# [ 6 33 39 15  9  5 37 40]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9712643678160919)
# [21 27 10 15  4  3 32 32]
# ('mask len = ', 42)
# ('mask true=', 35)
# ('reducedPrt len=', 35)
# ('prots len=', 42)
# ('trial acc=', 0.9252873563218391)
# [34  1 18 30 35  7 31 22]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9367816091954023)
# [41 15 24 29 19 18 13 31]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9425287356321839)
# [39 39 20 23 33 13 23 28]
# ('mask len = ', 42)
# ('mask true=', 36)
# ('reducedPrt len=', 36)
# ('prots len=', 42)
# ('trial acc=', 0.9655172413793104)
# [30 34 12 33 19 39 14 10]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9367816091954023)
# [15 34 11 40  6 36 12 24]
# ('mask len = ', 42)
# ('mask true=', 34)
# ('reducedPrt len=', 34)
# ('prots len=', 42)
# ('trial acc=', 0.9655172413793104)
# ('localBestAcc=', 0.9655172413793104)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.44943903,  0.24386551,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.11498628,  0.53901964,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.80866933,  0.85248161,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.49295834,  0.88989729,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.28470453,  0.34562658,  1.        ],
#        [ 0.19351653,  0.71856505,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.0457057 ,  0.68898032,  2.        ],
#        [ 0.04308614,  0.66669524,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.93299347,  0.57238019,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [ 0.97495786,  0.60074912,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.09879847,  0.86259056,  2.        ],
#        [ 0.10741981,  0.85986282,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ],
#        [ 0.07131628,  0.70995671,  2.        ]]))
# ('Accuracy with ', 34, 'prototypes=', 0.9655172413793104)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 34, 'prototypes...')
# ('reducedAccuracy=', 0.9655172413793104)
# [23  7  5 10 17  2]
# ('mask len = ', 34)
# ('mask true=', 28)
# ('reducedPrt len=', 28)
# ('prots len=', 34)
# ('trial acc=', 0.9540229885057471)
# [16 27 30 16 29  8]
# ('mask len = ', 34)
# ('mask true=', 29)
# ('reducedPrt len=', 29)
# ('prots len=', 34)
# ('trial acc=', 0.9195402298850575)
# [ 1  0 32 30 32  1]
# ('mask len = ', 34)
# ('mask true=', 30)
# ('reducedPrt len=', 30)
# ('prots len=', 34)
# ('trial acc=', 0.9367816091954023)
# [ 7 12  1 10 21 31]
# ('mask len = ', 34)
# ('mask true=', 28)
# ('reducedPrt len=', 28)
# ('prots len=', 34)
# ('trial acc=', 0.9540229885057471)
# [ 4 28 32 11 22  5]
# ('mask len = ', 34)
# ('mask true=', 28)
# ('reducedPrt len=', 28)
# ('prots len=', 34)
# ('trial acc=', 0.9310344827586207)
# [10 18 23 13 29 20]
# ('mask len = ', 34)
# ('mask true=', 28)
# ('reducedPrt len=', 28)
# ('prots len=', 34)
# ('trial acc=', 0.9195402298850575)
# [19 25  2 11  3 27]
# ('mask len = ', 34)
# ('mask true=', 28)
# ('reducedPrt len=', 28)
# ('prots len=', 34)
# ('trial acc=', 0.9712643678160919)
# [26 26 31 26  0 21]
# ('mask len = ', 34)
# ('mask true=', 30)
# ('reducedPrt len=', 30)
# ('prots len=', 34)
# ('trial acc=', 0.9425287356321839)
# [33 30 11  3 14 11]
# ('mask len = ', 34)
# ('mask true=', 29)
# ('reducedPrt len=', 29)
# ('prots len=', 34)
# ('trial acc=', 0.9712643678160919)
# [28 16  5 10  5 29]
# ('mask len = ', 34)
# ('mask true=', 29)
# ('reducedPrt len=', 29)
# ('prots len=', 34)
# ('trial acc=', 0.9540229885057471)
# ('localBestAcc=', 0.9712643678160919)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.11498628,  0.53901964,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.28470453,  0.34562658,  1.        ],
#        [ 0.19351653,  0.71856505,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.0457057 ,  0.68898032,  2.        ],
#        [ 0.04308614,  0.66669524,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.93299347,  0.57238019,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [ 0.97495786,  0.60074912,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.10741981,  0.85986282,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ]]))
# ('Accuracy with ', 29, 'prototypes=', 0.9712643678160919)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 29, 'prototypes...')
# ('reducedAccuracy=', 0.9712643678160919)
# [ 2  9  6  4 18]
# ('mask len = ', 29)
# ('mask true=', 24)
# ('reducedPrt len=', 24)
# ('prots len=', 29)
# ('trial acc=', 0.9655172413793104)
# [14 14 22 22 15]
# ('mask len = ', 29)
# ('mask true=', 26)
# ('reducedPrt len=', 26)
# ('prots len=', 29)
# ('trial acc=', 0.9712643678160919)
# [ 6 26  5  9  4]
# ('mask len = ', 29)
# ('mask true=', 24)
# ('reducedPrt len=', 24)
# ('prots len=', 29)
# ('trial acc=', 0.896551724137931)
# [21 28 11  1  1]
# ('mask len = ', 29)
# ('mask true=', 25)
# ('reducedPrt len=', 25)
# ('prots len=', 29)
# ('trial acc=', 0.9655172413793104)
# [22 15 22 19 19]
# ('mask len = ', 29)
# ('mask true=', 26)
# ('reducedPrt len=', 26)
# ('prots len=', 29)
# ('trial acc=', 0.9712643678160919)
# [12 17 26 28 26]
# ('mask len = ', 29)
# ('mask true=', 25)
# ('reducedPrt len=', 25)
# ('prots len=', 29)
# ('trial acc=', 0.9482758620689655)
# [24 25  3 20 28]
# ('mask len = ', 29)
# ('mask true=', 24)
# ('reducedPrt len=', 24)
# ('prots len=', 29)
# ('trial acc=', 0.9367816091954023)
# [10 18  7  0 18]
# ('mask len = ', 29)
# ('mask true=', 25)
# ('reducedPrt len=', 25)
# ('prots len=', 29)
# ('trial acc=', 0.9425287356321839)
# [ 7  8  8 25 18]
# ('mask len = ', 29)
# ('mask true=', 25)
# ('reducedPrt len=', 25)
# ('prots len=', 29)
# ('trial acc=', 0.9022988505747126)
# [ 3 20 26 25 25]
# ('mask len = ', 29)
# ('mask true=', 25)
# ('reducedPrt len=', 25)
# ('prots len=', 29)
# ('trial acc=', 0.9310344827586207)
# ('localBestAcc=', 0.9712643678160919)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.11498628,  0.53901964,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.28470453,  0.34562658,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.04308614,  0.66669524,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [ 0.97495786,  0.60074912,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.10741981,  0.85986282,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ]]))
# ('Accuracy with ', 26, 'prototypes=', 0.9712643678160919)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 26, 'prototypes...')
# ('reducedAccuracy=', 0.9712643678160919)
# [11 12 17 21 18]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9540229885057471)
# [11 23 11 14 20]
# ('mask len = ', 26)
# ('mask true=', 22)
# ('reducedPrt len=', 22)
# ('prots len=', 26)
# ('trial acc=', 0.9482758620689655)
# [18 25 17  8 22]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9827586206896551)
# [20 20 11  7  1]
# ('mask len = ', 26)
# ('mask true=', 22)
# ('reducedPrt len=', 22)
# ('prots len=', 26)
# ('trial acc=', 0.9482758620689655)
# [14 16 18 21  8]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9712643678160919)
# [25 12  3 14  5]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9252873563218391)
# [24  1 14  8 12]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9425287356321839)
# [ 4  5 17 16  2]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9712643678160919)
# [22 14  3  8 17]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9770114942528736)
# [18  4 24 14 22]
# ('mask len = ', 26)
# ('mask true=', 21)
# ('reducedPrt len=', 21)
# ('prots len=', 26)
# ('trial acc=', 0.9770114942528736)
# ('localBestAcc=', 0.9770114942528736)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.18826912,  0.62329352,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17328106,  0.89852485,  2.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.54594632,  0.43481396,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ],
#        [ 0.80100914,  0.70595707,  2.        ]]))
# ('Accuracy with ', 21, 'prototypes=', 0.9770114942528736)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 21, 'prototypes...')
# ('reducedAccuracy=', 0.9770114942528736)
# [ 9 10  6 14]
# ('mask len = ', 21)
# ('mask true=', 17)
# ('reducedPrt len=', 17)
# ('prots len=', 21)
# ('trial acc=', 0.9827586206896551)
# [15 18  9  2]
# ('mask len = ', 21)
# ('mask true=', 17)
# ('reducedPrt len=', 17)
# ('prots len=', 21)
# ('trial acc=', 0.9712643678160919)
# [7 7 4 5]
# ('mask len = ', 21)
# ('mask true=', 18)
# ('reducedPrt len=', 18)
# ('prots len=', 21)
# ('trial acc=', 0.9080459770114943)
# [ 7 20  4 14]
# ('mask len = ', 21)
# ('mask true=', 17)
# ('reducedPrt len=', 17)
# ('prots len=', 21)
# ('trial acc=', 0.9827586206896551)
# [ 2  5 19 19]
# ('mask len = ', 21)
# ('mask true=', 18)
# ('reducedPrt len=', 18)
# ('prots len=', 21)
# ('trial acc=', 0.9770114942528736)
# [11  1 20  4]
# ('mask len = ', 21)
# ('mask true=', 17)
# ('reducedPrt len=', 17)
# ('prots len=', 21)
# ('trial acc=', 0.9425287356321839)
# [18 10 20 14]
# ('mask len = ', 21)
# ('mask true=', 17)
# ('reducedPrt len=', 17)
# ('prots len=', 21)
# ('trial acc=', 0.9827586206896551)
# [ 1  1 18 16]
# ('mask len = ', 21)
# ('mask true=', 18)
# ('reducedPrt len=', 18)
# ('prots len=', 21)
# ('trial acc=', 0.9712643678160919)
# [11 13 12 11]
# ('mask len = ', 21)
# ('mask true=', 18)
# ('reducedPrt len=', 18)
# ('prots len=', 21)
# ('trial acc=', 0.9655172413793104)
# [14 18 11 16]
# ('mask len = ', 21)
# ('mask true=', 17)
# ('reducedPrt len=', 17)
# ('prots len=', 21)
# ('trial acc=', 0.9712643678160919)
# ('localBestAcc=', 0.9827586206896551)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.47014045,  0.9495859 ,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.58589442,  0.54350006,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.80504788,  0.70623956,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ]]))
# ('Accuracy with ', 17, 'prototypes=', 0.9827586206896551)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 17, 'prototypes...')
# ('reducedAccuracy=', 0.9827586206896551)
# [16 12 10]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9367816091954023)
# [ 7 10 11]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9712643678160919)
# [14 15  2]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9885057471264368)
# [ 2 14 10]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9712643678160919)
# [10 11 15]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9885057471264368)
# [8 2 1]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9827586206896551)
# [16  2  7]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9482758620689655)
# [16  8 12]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9482758620689655)
# [15  8 11]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9885057471264368)
# [ 8  4 16]
# ('mask len = ', 17)
# ('mask true=', 14)
# ('reducedPrt len=', 14)
# ('prots len=', 17)
# ('trial acc=', 0.9425287356321839)
# ('localBestAcc=', 0.9885057471264368)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.73811754,  0.82641614,  1.        ],
#        [ 0.56335524,  0.56485107,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ]]))
# ('Accuracy with ', 14, 'prototypes=', 0.9885057471264368)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 14, 'prototypes...')
# ('reducedAccuracy=', 0.9885057471264368)
# [7 6]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9827586206896551)
# [8 4]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9885057471264368)
# [ 4 12]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9885057471264368)
# [10  7]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9885057471264368)
# [11 12]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9942528735632183)
# [ 7 11]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9942528735632183)
# [1 2]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9942528735632183)
# [9 0]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9770114942528736)
# [13 11]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9655172413793104)
# [13  7]
# ('mask len = ', 14)
# ('mask true=', 12)
# ('reducedPrt len=', 12)
# ('prots len=', 14)
# ('trial acc=', 0.9597701149425287)
# ('localBestAcc=', 0.9942528735632183)
# ('localBestPrt=', array([[ 0.31663836,  0.85293413,  1.        ],
#        [ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ],
#        [ 0.46607926,  0.44650381,  2.        ]]))
# ('Accuracy with ', 12, 'prototypes=', 0.9942528735632183)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 12, 'prototypes...')
# ('reducedAccuracy=', 0.9942528735632183)
# [1 1]
# ('mask len = ', 12)
# ('mask true=', 11)
# ('reducedPrt len=', 11)
# ('prots len=', 12)
# ('trial acc=', 0.9080459770114943)
# [ 2 11]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [6 2]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [ 2 10]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [10  4]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [9 1]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9080459770114943)
# [ 4 10]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [8 3]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [8 2]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# [ 0 11]
# ('mask len = ', 12)
# ('mask true=', 10)
# ('reducedPrt len=', 10)
# ('prots len=', 12)
# ('trial acc=', 0.9942528735632183)
# ('localBestAcc=', 0.9942528735632183)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.86521484,  0.57988733,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.17629742,  0.1979733 ,  2.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Accuracy with ', 10, 'prototypes=', 0.9942528735632183)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 10, 'prototypes...')
# ('reducedAccuracy=', 0.9942528735632183)
# [3 4]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.9885057471264368)
# [6 7]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.9885057471264368)
# [1 9]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.8218390804597702)
# [0 1]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.8505747126436781)
# [7 4]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.9942528735632183)
# [1 4]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.9942528735632183)
# [9 2]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 0.8103448275862069)
# [1 1]
# ('mask len = ', 10)
# ('mask true=', 9)
# ('reducedPrt len=', 9)
# ('prots len=', 10)
# ('trial acc=', 0.9942528735632183)
# [8 3]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 1.0)
# [2 8]
# ('mask len = ', 10)
# ('mask true=', 8)
# ('reducedPrt len=', 8)
# ('prots len=', 10)
# ('trial acc=', 1.0)
# ('localBestAcc=', 1.0)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.76867451,  0.75870494,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Accuracy with ', 8, 'prototypes=', 1.0)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 8, 'prototypes...')
# ('reducedAccuracy=', 1.0)
# [7]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 0.6666666666666666)
# [0]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 0.8505747126436781)
# [6]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# [2]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# [5]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# [4]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# [7]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 0.6666666666666666)
# [6]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# [3]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# [5]
# ('mask len = ', 8)
# ('mask true=', 7)
# ('reducedPrt len=', 7)
# ('prots len=', 8)
# ('trial acc=', 1.0)
# ('localBestAcc=', 1.0)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.81683579,  0.63216542,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Accuracy with ', 7, 'prototypes=', 1.0)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 7, 'prototypes...')
# ('reducedAccuracy=', 1.0)
# [3]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 1.0)
# [5]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 0.9942528735632183)
# [6]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 0.6666666666666666)
# [2]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 1.0)
# [6]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 0.6666666666666666)
# [2]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 1.0)
# [6]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 0.6666666666666666)
# [5]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 0.9942528735632183)
# [2]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 1.0)
# [1]
# ('mask len = ', 7)
# ('mask true=', 6)
# ('reducedPrt len=', 6)
# ('prots len=', 7)
# ('trial acc=', 1.0)
# ('localBestAcc=', 1.0)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.8798223 ,  0.71446795,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Accuracy with ', 6, 'prototypes=', 1.0)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 6, 'prototypes...')
# ('reducedAccuracy=', 1.0)
# [2]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 1.0)
# [5]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 0.6666666666666666)
# [1]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 1.0)
# [0]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 0.8505747126436781)
# [4]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 0.9942528735632183)
# [2]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 1.0)
# [5]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 0.6666666666666666)
# [5]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 0.6666666666666666)
# [0]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 0.8505747126436781)
# [3]
# ('mask len = ', 6)
# ('mask true=', 5)
# ('reducedPrt len=', 5)
# ('prots len=', 6)
# ('trial acc=', 1.0)
# ('localBestAcc=', 1.0)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.94649859,  0.24122109,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Accuracy with ', 5, 'prototypes=', 1.0)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 5, 'prototypes...')
# ('reducedAccuracy=', 1.0)
# [4]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 0.6666666666666666)
# [1]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 1.0)
# [3]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 0.8333333333333334)
# [1]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 1.0)
# [2]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 1.0)
# [0]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 0.8505747126436781)
# [0]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 0.8505747126436781)
# [4]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 0.6666666666666666)
# [1]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 1.0)
# [3]
# ('mask len = ', 5)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 5)
# ('trial acc=', 0.8333333333333334)
# ('localBestAcc=', 1.0)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Accuracy with ', 4, 'prototypes=', 1.0)
# -------------------------------------------------
# ('Trying ', 10, 'reductions of ', 4, 'prototypes...')
# ('reducedAccuracy=', 1.0)
# []
# ('mask len = ', 4)
# ('mask true=', 4)
# ('reducedPrt len=', 4)
# ('prots len=', 4)
# ('localBestAcc=', 0)
# ('localBestPrt=', array([[ 0.10320404,  0.3609402 ,  1.        ],
#        [ 0.90030526,  0.39300604,  1.        ],
#        [ 0.65775291,  0.81150006,  1.        ],
#        [ 0.51311138,  0.3374019 ,  2.        ]]))
# ('Best params: ', 4, ' at accuracy=', 1.0)
# [[ 0.10320404  0.3609402   1.        ]
#  [ 0.90030526  0.39300604  1.        ]
#  [ 0.65775291  0.81150006  1.        ]
#  [ 0.51311138  0.3374019   2.        ]]

# %%
predictedClasses=runTestSet(X, prots)

plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.title("Test set classification(optimized prototypes)")
col={0:'bo',1:'go', 2:'co'}
for i in range(len(X[:,0])):
    plt.plot(X[i,0],X[i,1],col[int(predictedClasses[i])])

plt.plot(prots[:,0],prots[:,1],'ro')

plt.axis([0, 1.5, 0, 1.5])
plt.show()
